# %% [markdown]
# # HOUSING PRICE PREDICTOR

# %% [markdown]
# ## We import the necessary libraries
# - numpy:  for numerical computing
# - pandas: for data manipulation and analysis
# - matplotlib:  Imports the pyplot module from Matplotlib for creating plots
# - seaborn: for statistical data visualization
# - mp_toolkits: for additional tools and utilities in Matplotlib

# %%
#importing libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import mpl_toolkits
# %matplotlib inline   
#A magic command for Jupyter Notebooks, enabling inline Matplotlib plots.

# %% [markdown]
# ### Loading the Dataset

# %%
data= pd.read_csv("D:\DATA SCIENCE PROJECTS\kc_house_data.csv")

# %%
data.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
data.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %% [markdown]
# ### Visualization
# 1. **Bedroom Distribution**
# - illustrating the distribution of the number of bedrooms in the dataset, with axes labeled and spines removed for clarity.

# %%
#number of bedrooms
sns.set_style('darkgrid')
data['bedrooms'].value_counts().plot(kind='bar')
plt.title('Number of bedrooms')
plt.xlabel('Bedrooms')
plt.ylabel('Count')
sns.despine
# Out:
# <function seaborn.utils.despine(fig=None, ax=None, top=True, right=True, left=False, bottom=False, offset=None, trim=False)>

# %% [markdown]
# 2. **Spatial Distribution: Latitude and Longitude**
# - The graph is a joint plot displaying the spatial relationship between latitude and longitude coordinates, with histograms showing their distributions, and spines removed for clarity.ance.

# %%
#latitdue and longitude

plt.figure(figsize=(10,10))
sns.jointplot(x=data.lat.values, y=data.long.values, size=10)
plt.ylabel('Longitude', fontsize=12)
plt.xlabel('Latitude', fontsize=12)
plt.show()
sns.despine()

# %% [markdown]
# 3. **Analyzing Price vs Square Feet Relationship**
# - Scatter plot depicting the relationship between house price and square footage of living space, with price on the x-axis, square feet on the y-axis, and labeled axes for clarity.

# %%
#price vs square feet

plt.scatter(data.price, data.sqft_living)
plt.title('Price vs Square feet')
plt.xlabel('Price')
plt.ylabel('Square feet')
# Out:
# Text(0, 0.5, 'Square feet')

# %% [markdown]
# 4. **Exploring Price vs Location Relationship**
# - Scatter plot illustrating the relationship between house price and location, with price on the x-axis, longitude on the y-axis, and labeled axes providing insight into the geographical distribution of prices.

# %%
#price vs location of the area

plt.scatter(data.price, data.long)
plt.title('Price vs Location of the area')
plt.xlabel('Price')
plt.ylabel('Location of the area')
# Out:
# Text(0, 0.5, 'Location of the area')

# %% [markdown]
# 5. **Examining Latitude vs Price Correlation**
# - Scatter plot visualizing the correlation between house prices and latitude, with price on the x-axis, latitude on the y-axis, and labeled axes providing insights into spatial pricing patterns.

# %%
#latitude vs price

plt.scatter(data.price, data.lat)
plt.title('Latitude vs Price')
plt.xlabel('Price')
plt.ylabel('Latitude')
# Out:
# Text(0, 0.5, 'Latitude')

# %% [markdown]
# 6. **Investigating Bedrooms vs Price Relationship**
# - Scatter plot illustrating the relationship between the number of bedrooms and house prices, with bedrooms on the x-axis, price on the y-axis, and labels for clarity, along with spines removed for a cleaner appearance.

# %%
#bedrooms vs price

plt.scatter(data.bedrooms, data.price)
plt.title('Bedrooms and Price')
plt.xlabel('Bedrooms')
plt.ylabel('Price')
plt.show()
sns.despine()

# %% [markdown]
# 7. **Analyzing Total Square Feet (Living and Basement) vs Price**
# - Scatter plot exploring the combined square footage of living and basement areas in relation to house prices, with the total square footage on the x-axis, price on the y-axis, and labeled axes for interpretation.

# %%
#Square feet living and square feet basement vs Price
plt.scatter((data['sqft_living']+data['sqft_basement']), data['price'])
plt.title('Square feet living and square feet basement vs Price')
plt.xlabel('Square feet living and Square feet basement')
plt.ylabel('Price')
# Out:
# Text(0, 0.5, 'Price')

# %% [markdown]
# 8. **Examining Waterfront Property Impact on Price**
# - Scatter plot illustrating the relationship between waterfront property status (0 for no waterfront, 1 for waterfront) and house prices, with waterfront status on the x-axis, price on the y-axis, and labeled axes for clarity.

# %%
#waterfront vs price
plt.scatter(data.waterfront, data.price)
plt.title('Waterfront vs price (0=no waterfront)')
plt.xlabel('Waterfront')
plt.ylabel('Price')
# Out:
# Text(0, 0.5, 'Price')

# %% [markdown]
# ##### Creating new dataframe and dropping unnecesseary columns

# %%
#dropping id and price
train1= data.drop(['id','price'], axis=1)

# %%
train1.head()
# Out:
#               date  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0  20141013T000000         3       1.00         1180      5650     1.0
# 1  20141209T000000         3       2.25         2570      7242     2.0
# 2  20150225T000000         2       1.00          770     10000     1.0
# 3  20141209T000000         4       3.00         1960      5000     1.0
# 4  20150218T000000         3       2.00         1680      8080     1.0
#
#    waterfront  view  condition  grade  sqft_above  sqft_basement  yr_built  \
# 0           0     0          3      7        1180              0      1955
# 1           0     0          3      7        2170            400      1951
# 2           0     0          3      6         770              0      1933
# 3           0     0          5      7        1050            910      1965
# 4           0     0          3      8        1680              0      1987
#
#    yr_renovated  zipcode      lat     long  sqft_living15  sqft_lot15
# ...

# %% [markdown]
# 9. **Analyzing Distribution of Number of Floors**
# - Bar plot illustrating the frequency distribution of the number of floors in the dataset, with the number of floors on the x-axis and the frequency on the y-axis, along with labels for clarity.

# %%
data.floors.value_counts().plot(kind='bar')
plt.title('Distribution of Number of Floors')
plt.xlabel('Number of floors')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# 10. **Exploring Number of Floors vs Price**
# - Scatter plot depicting the relationship between the number of floors and house prices, with the number of floors on the x-axis, price on the y-axis, and labeled axes for interpretation.

# %%
plt.scatter(data.floors,data.price)
plt.title('Number of floors vs price')
plt.xlabel('Number of floors')
plt.ylabel('Price')
# Out:
# Text(0, 0.5, 'Price')

# %% [markdown]
# 11. **Examining Property Condition vs Price**
# - Scatter plot illustrating the relationship between property condition and house prices, with the condition rating on the x-axis, price on the y-axis, and labeled axes for interpretation.

# %%
plt.scatter(data.condition, data.price)
plt.title('Condition vs Price')
plt.xlabel('Condition')
plt.ylabel('Price')
# Out:
# Text(0, 0.5, 'Price')

# %% [markdown]
# 12. **Identifying Pricey Locations by Zipcode**
# - Scatter plot visualizing house prices across different zip codes, with zip codes on the x-axis and prices on the y-axis, providing insights into the variation of housing prices across different areas.

# %%
#Which is the pricey location by zipcode
plt.scatter(data.zipcode, data.price)
plt.title('Which is the pricey location by zipcode')
plt.xlabel('Zipcode')
plt.ylabel('Price')
# Out:
# Text(0, 0.5, 'Price')

# %% [markdown]
# ### Preparing Data for Linear Regression Modeling

# %%
from sklearn.linear_model import LinearRegression

# %%
reg= LinearRegression()

# %%
labels=data['price']
conv_dates=[1 if values==2014 else 0 for values in data.date]
data['date']= conv_dates
train1=data.drop(['id', 'price'], axis=1)

# %% [markdown]
# ### Splitting Data and Training Linear Regression Model
#
# - The code splits the data into training and testing sets using train_test_split from scikit-learn, with 90% of the data used for training and 10% for testing. It then fits a linear regression model (reg) to the training data.

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train,  y_test = train_test_split(train1, labels, test_size=0.10, random_state=2)

# %%
reg.fit(x_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ### Training Gradient Boosting Regressor
#
# - The code initializes a Gradient Boosting Regressor (clf) from the scikit-learn ensemble module, with specified hyperparameters such as the number of estimators, maximum depth, minimum samples split, learning rate, and loss function. It then fits the regressor to the training data.

# %%
from sklearn import ensemble
clf = ensemble.GradientBoostingRegressor(n_estimators=400, max_depth=5, 
                                         min_samples_split=2, 
                                        learning_rate=0.1,
                                        loss='squared_error')

# %%
clf.fit(x_train,y_train)

# %%
clf.score(x_test, y_test)

# %% [markdown]
# ### Assessing Model Performance and Tuning Parameters
# - The code evaluates the performance of the model on the test set using the score method. It then calculates the loss on the test set for each stage of the gradient boosting process using staged_predict and stores the results in an array t_sc. Finally, it generates an array testsc representing the number of estimators.

# %%
params={'n_estimators': 400}
t_sc= np.zeros((params['n_estimators']), dtype =np.float64)

# %%
y_pred =reg.predict(x_test)

# %%
for i , y_pred in enumerate(clf.staged_predict(x_test)):
    t_sc[i]= clf.loss_(y_test, y_pred)

# %%
testsc=np.arange((params['n_estimators']))+1

# %% [markdown]
# 13. **Visualizing Model Deviance**
# - The plot compares the training set deviance (blue line) and test set deviance (red line) as the number of estimators increases. This visualization helps in assessing the model's training progress and identifying overfitting or underfitting tendencies.

# %%
#
plt.figure(figsize=(12,6))
plt.subplot(1,2,1)
plt.plot(testsc, clf.train_score_, 'b-', label='Set dev train')
plt.plot(testsc, t_sc, 'r-', label='set dev test')

# %% [markdown]
# ### Performing Principal Component Analysis (PCA)
#
# - The code imports the PCA class from scikit-learn's decomposition module and performs PCA on the scaled features of the training data using the fit_transform method.

# %%
from sklearn.preprocessing import scale
from sklearn.decomposition import PCA

# %%
pca= PCA()

# %%
pca.fit_transform(scale(train1))
